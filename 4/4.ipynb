# %% [markdown]
# # SALARY PREDICTION - USING LINEAR REGRESSION

# %%
import pandas as pd                        # pandas is used for Data Manpulations, it is renamed as "pd"
import matplotlib.pyplot as plt            # for Visualization we are using matplotlib, is is rename as "plt"
dataset = pd.read_csv('Salary_Data.csv')   # dataset as object,in an storing Salary_Data,pd- Package, read_csv - function, Salary_Data.csv is Dataset we are passing as parameter to this function
dataset.head(11)                            # head means only top 5 will be printing that is default, if i mention any number n, 0 to (n-1) it will display
# Out:
#     Years Experience  Salary
# 0                1.1   39343
# 1                1.3   46205
# 2                1.5   37731
# 3                2.0   43525
# 4                2.2   39891
# 5                2.9   56642
# 6                3.0   60150
# 7                3.2   54445
# 8                3.2   64445
# 9                3.7   57189
# 10               3.9   63218

# %%
x = dataset.iloc[:, : -1].values #display x-axis values in reverse order
y = dataset.iloc[ :, 1].values   #display y-axis in same order

# %%
from sklearn.model_selection import train_test_split       #split dataset into two diffrent parts training and testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)   # Fit simple Linear Regression model to training set
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)  #Make Prediction

# %%
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, regressor.predict(x_train),color = 'blue')
plt.title('Salary Vs Experience (Training Set)')
plt.xlabel('Years of Experience :')
plt.ylabel('Salary :')
plt.show()                 #Visualizing Training Set

# %%
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_train, regressor.predict(x_train),color = 'blue')
plt.title('Salary Vs Experience (Test Set)')
plt.xlabel('Years of Experience :')
plt.ylabel('Salary :')
plt.show()              #Visualizing Testing Set

# %%
new_salary_pred = regressor.predict([[20]])
print(' The Predicted Salary of a Person with 13 Years of Experience is : ', new_salary_pred)
# Out:
#  The Predicted Salary of a Person with 13 Years of Experience is :  [213735.04110648]
